# %%
a = None

"".join(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-3404c53cafc0> in <module>()
#       1 a = None
#       2
# ----> 3 "".join(a)
#
# TypeError: can only join an iterable
