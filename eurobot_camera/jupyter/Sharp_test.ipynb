# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import copy

image = cv2.imread("/home/nuka-cola/Downloads/XIV2S_2BkDk.jpg")
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
sharp = copy.copy(image)

# kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
# sharp_gray = cv2.filter2D(image_gray, -1, kernel)
# sharp = cv2.cvtColor(sharp_gray, cv2.COLOR_GRAY2BGR)

blur = cv2.GaussianBlur(image, (5, 5), 3)
sharp = cv2.addWeighted(image, 1.7, blur, -0.7, 0 )


fig, ax = plt.subplots(1,1,figsize=(4,4), dpi=500)
plt.imshow(image)

fig, ax = plt.subplots(1,1,figsize=(4,4), dpi=500)
plt.imshow(sharp)
