# %%
import numpy as np

import cv2
from skimage import exposure
from skimage import filters
import matplotlib.pyplot as plt


image = cv2.imread("/home/nuka-cola/.ros/camera_image.png")

# H: 0 - 180, S: 0 - 255, V: 0 - 255

hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
h, s, v = cv2.split(hsv_image)

print ("After:", s)
s = s + 50
print ("Before:", s)



hsv_image[:,:,1] = s
hsv_image[:,:,2] = v

bgr_image = cv2.cvtColor(hsv_image, cv2.COLOR_HSV2RGB)


fig, ax = plt.subplots(1,1,figsize=(4,4), dpi=500)
plt.imshow(bgr_image)
# Out:
# ('After:', array([[ 65,  63,  60, ...,  32,  32,  32],
#        [ 65,  65,  63, ...,  32,  32,  39],
#        [ 68,  65,  65, ...,  32,  39,  39],
#        ...,
#        [133, 133, 132, ...,  91,  90,  92],
#        [135, 134, 133, ...,  93,  92,  91],
#        [136, 135, 135, ...,  95,  94,  93]], dtype=uint8))
# ('Before:', array([[115, 113, 110, ...,  82,  82,  82],
#        [115, 115, 113, ...,  82,  82,  89],
#        [118, 115, 115, ...,  82,  89,  89],
#        ...,
#        [183, 183, 182, ..., 141, 140, 142],
#        [185, 184, 183, ..., 143, 142, 141],
#        [186, 185, 185, ..., 145, 144, 143]], dtype=uint8))
