# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import copy

image = cv2.imread("/home/nuka-cola/Downloads/XIV2S_2BkDk.jpg")

hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
h, s, v = cv2.split(hsv_image)

print ("After:", s)
v = v + 150
print ("Before:", s)

hsv_image[:,:,1] = s
hsv_image[:,:,2] = v

bgr_image = cv2.cvtColor(hsv_image, cv2.COLOR_HSV2RGB)


blur = cv2.GaussianBlur(bgr_image, (5, 5), 3)

image_gray = cv2.cvtColor(bgr_image, cv2.COLOR_RGB2GRAY)



th = cv2.adaptiveThreshold(image_gray,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,13,2)

fig, ax = plt.subplots(1,1,figsize=(4,4), dpi=500)
plt.imshow(image)

fig, ax = plt.subplots(1,1,figsize=(4,4), dpi=500)
plt.imshow(th)
# Out:
# ('After:', array([[ 14,  17,  17, ...,  91,  96, 110],
#        [ 15,  19,  16, ..., 138, 136, 130],
#        [ 14,  19,  19, ..., 157, 153, 150],
#        ...,
#        [125, 121, 131, ...,  69,  73,  71],
#        [122, 126, 117, ...,  66,  80,  70],
#        [124, 128, 120, ...,  66,  80,  70]], dtype=uint8))
# ('Before:', array([[ 14,  17,  17, ...,  91,  96, 110],
#        [ 15,  19,  16, ..., 138, 136, 130],
#        [ 14,  19,  19, ..., 157, 153, 150],
#        ...,
#        [125, 121, 131, ...,  69,  73,  71],
#        [122, 126, 117, ...,  66,  80,  70],
#        [124, 128, 120, ...,  66,  80,  70]], dtype=uint8))
