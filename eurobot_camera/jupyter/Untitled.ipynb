# %%
import cv2
import numpy as np
import copy

import matplotlib.pyplot as plt

# %%
image = cv2.imread("/home/nuka-cola/Downloads/s6nWvy872k4.jpg")
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
sharp = copy.copy(image)

hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
h, s, v = cv2.split(hsv_image)

s_cutoff, v_cutoff = 0.5, 0.5
s_gain, v_gain = 10, 10

s = skimage.exposure.adjust_sigmoid(s, s_cutoff, s_gain)
v = skimage.exposure.adjust_sigmoid(v, v_cutoff, v_gain)

hsv_image[:, :, 1] = s
hsv_image[:, :, 2] = v

bgr_image = cv2.cvtColor(hsv_image, cv2.COLOR_HSV2RGB)

fig, ax = plt.subplots(1,1,figsize=(4,4), dpi=500)
plt.imshow(image)

fig, ax = plt.subplots(1,1,figsize=(4,4), dpi=500)
plt.imshow(bgr_image)

# %%
LAB_REDIUM=[48.04335752, 74.08054268, 62.1584816 ]
LAB_GREENIUM=[88.52609404, -79.01588508, 81.76924998]
LAB_BLUEIUM=[61.83055688, 4.32627342, -59.4598142]


print ("LAB_GRENIUM", LAB_GREENIUM)
print ("LAB_REDIUM", LAB_REDIUM)
print ("LAB_BLUEIUM", LAB_BLUEIUM)



LAB_COLORS = np.array( (LAB_REDIUM,LAB_GREENIUM,LAB_BLUEIUM), dtype=np.int8)
print ("LAB_COLORS      ", LAB_COLORS  )
# Out:
# ('LAB_GRENIUM', [88.52609404, -79.01588508, 81.76924998])
# ('LAB_REDIUM', [48.04335752, 74.08054268, 62.1584816])
# ('LAB_BLUEIUM', [61.83055688, 4.32627342, -59.4598142])
# ('LAB_COLORS      ', array([[ 48,  74,  62],
#        [ 88, -79,  81],
#        [ 61,   4, -59]], dtype=int8))

# %%
print image.shape[:2]
# Out:
# (1349, 1080)
